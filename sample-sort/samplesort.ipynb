# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %%
#1_trial is a name of a folder containing the cali files, you may create a folder with a different name and replace the folder name here
tk = th.Thicket.from_caliperreader("samplesort.cali")

# %%
print(tk.tree(metric_column="Avg time/rank", precision=5))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 1.61089 main
# ├─ 0.00003 MPI_Init
# ├─ 0.00796 data_init_runtime
# ├─ 0.04400 comm
# │  ├─ 0.04294 comm_large
# │  │  ├─ 0.04174 MPI_Recv
# │  │  └─ 0.00077 MPI_Send
# │  └─ 0.00920 comm_small
# │     └─ 0.00916 MPI_Send
# ├─ 0.00249 comp
# │  ├─ 0.00002 comp_small
# │  └─ 0.00277 comp_large
# ├─ 0.00008 correctness_check
# ├─ 0.00000 MPI_Finalize
# ├─ 0.00001 MPI_Initialized
# ├─ 0.00001 MPI_Finalized
# └─ 0.02370 MPI_Comm_dup
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 1.61 indices: {'profile': 665975200})
# █ 1.45 - 1.61
# █ 1.13 - 1.45
# █ 0.81 - 1.13
# █ 0.48 - 0.81
# █ 0.16 - 0.48
# █ 0.00 - 0.16
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.dataframe
# Out:
#                                                                nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475   1.0
# {'name': 'MPI_Init', 'type': 'function'}          1223936475   2.0
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475   3.0
# {'name': 'comm', 'type': 'function'}              1223936475   6.0
# {'name': 'comm_large', 'type': 'function'}        1223936475   9.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475  11.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475  10.0
# {'name': 'comm_small', 'type': 'function'}        1223936475   7.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475   8.0
# {'name': 'comp', 'type': 'function'}              1223936475   4.0
# {'name': 'comp_small', 'type': 'function'}        1223936475   5.0
# {'name': 'comp_large', 'type': 'function'}        1223936475  17.0
# {'name': 'comp', 'type': 'function'}              1223936475  18.0
# {'name': 'comm', 'type': 'function'}              1223936475  19.0
# {'name': 'comm_large', 'type': 'function'}        1223936475  20.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475  21.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475  22.0
# {'name': 'comp', 'type': 'function'}              1223936475  23.0
# {'name': 'comp_large', 'type': 'function'}        1223936475  24.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475  25.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475  26.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475  27.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475  28.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475  29.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475  12.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475  13.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475  14.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475  15.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475  16.0
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475  regionprofile
# {'name': 'MPI_Init', 'type': 'function'}          1223936475  regionprofile
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475  regionprofile
# {'name': 'comm', 'type': 'function'}              1223936475  regionprofile
# {'name': 'comm_large', 'type': 'function'}        1223936475  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          1223936475  regionprofile
# {'name': 'comm_small', 'type': 'function'}        1223936475  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          1223936475  regionprofile
# {'name': 'comp', 'type': 'function'}              1223936475  regionprofile
# {'name': 'comp_small', 'type': 'function'}        1223936475  regionprofile
# {'name': 'comp_large', 'type': 'function'}        1223936475  regionprofile
# {'name': 'comp', 'type': 'function'}              1223936475  regionprofile
# {'name': 'comm', 'type': 'function'}              1223936475  regionprofile
# {'name': 'comm_large', 'type': 'function'}        1223936475  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          1223936475  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475  regionprofile
# {'name': 'comp', 'type': 'function'}              1223936475  regionprofile
# {'name': 'comp_large', 'type': 'function'}        1223936475  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 1223936475  regionprofile
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475  regionprofile
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475  regionprofile
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475  regionprofile
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 1223936475  regionprofile
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475  regionprofile
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475  regionprofile
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475  regionprofile
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475       0.698449
# {'name': 'MPI_Init', 'type': 'function'}          1223936475       0.000027
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475       0.000072
# {'name': 'comm', 'type': 'function'}              1223936475       0.001412
# {'name': 'comm_large', 'type': 'function'}        1223936475       0.001391
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475       0.001362
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475       0.002028
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000086
# {'name': 'comp', 'type': 'function'}              1223936475       0.000083
# {'name': 'comp_small', 'type': 'function'}        1223936475       0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475       0.000025
# {'name': 'comp', 'type': 'function'}              1223936475       0.049859
# {'name': 'comm', 'type': 'function'}              1223936475       0.000362
# {'name': 'comm_large', 'type': 'function'}        1223936475       0.000349
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000081
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475       0.000149
# {'name': 'comp', 'type': 'function'}              1223936475       0.000012
# {'name': 'comp_large', 'type': 'function'}        1223936475       0.000005
# {'name': 'correctness_check', 'type': 'function'} 1223936475       0.000004
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475       0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475       0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       0.020074
# {'name': 'correctness_check', 'type': 'function'} 1223936475       0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475       0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475       0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       0.019761
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475       0.762114
# {'name': 'MPI_Init', 'type': 'function'}          1223936475       0.000044
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475       0.000072
# {'name': 'comm', 'type': 'function'}              1223936475       0.041215
# {'name': 'comm_large', 'type': 'function'}        1223936475       0.039177
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475       0.039014
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475       0.002028
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000086
# {'name': 'comp', 'type': 'function'}              1223936475       0.069087
# {'name': 'comp_small', 'type': 'function'}        1223936475       0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475       0.000035
# {'name': 'comp', 'type': 'function'}              1223936475       0.069046
# {'name': 'comm', 'type': 'function'}              1223936475       0.029142
# {'name': 'comm_large', 'type': 'function'}        1223936475       0.029129
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000095
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475       0.028921
# {'name': 'comp', 'type': 'function'}              1223936475       0.000048
# {'name': 'comp_large', 'type': 'function'}        1223936475       0.000039
# {'name': 'correctness_check', 'type': 'function'} 1223936475       0.000004
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475       0.019772
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475       0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       0.050579
# {'name': 'correctness_check', 'type': 'function'} 1223936475       0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475       0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475       0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       0.019761
#
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475       0.706986
# {'name': 'MPI_Init', 'type': 'function'}          1223936475       0.000031
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475       0.000072
# {'name': 'comm', 'type': 'function'}              1223936475       0.013666
# {'name': 'comm_large', 'type': 'function'}        1223936475       0.013420
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475       0.013373
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475       0.002028
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000086
# {'name': 'comp', 'type': 'function'}              1223936475       0.051887
# {'name': 'comp_small', 'type': 'function'}        1223936475       0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475       0.000028
# {'name': 'comp', 'type': 'function'}              1223936475       0.058324
# {'name': 'comm', 'type': 'function'}              1223936475       0.015519
# {'name': 'comm_large', 'type': 'function'}        1223936475       0.015506
# {'name': 'MPI_Send', 'type': 'function'}          1223936475       0.000089
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475       0.015302
# {'name': 'comp', 'type': 'function'}              1223936475       0.000032
# {'name': 'comp_large', 'type': 'function'}        1223936475       0.000023
# {'name': 'correctness_check', 'type': 'function'} 1223936475       0.000004
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475       0.002476
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475       0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       0.040214
# {'name': 'correctness_check', 'type': 'function'} 1223936475       0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475       0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475       0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       0.019761
#
#                                                               Total time  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475    6.362876
# {'name': 'MPI_Init', 'type': 'function'}          1223936475    0.000276
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475    0.000072
# {'name': 'comm', 'type': 'function'}              1223936475    0.122990
# {'name': 'comm_large', 'type': 'function'}        1223936475    0.120779
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475    0.120358
# {'name': 'MPI_Send', 'type': 'function'}          1223936475    0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475    0.002028
# {'name': 'MPI_Send', 'type': 'function'}          1223936475    0.000086
# {'name': 'comp', 'type': 'function'}              1223936475    0.466981
# {'name': 'comp_small', 'type': 'function'}        1223936475    0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475    0.000224
# {'name': 'comp', 'type': 'function'}              1223936475    0.466590
# {'name': 'comm', 'type': 'function'}              1223936475    0.124154
# {'name': 'comm_large', 'type': 'function'}        1223936475    0.124045
# {'name': 'MPI_Send', 'type': 'function'}          1223936475    0.000713
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475    0.122418
# {'name': 'comp', 'type': 'function'}              1223936475    0.000258
# {'name': 'comp_large', 'type': 'function'}        1223936475    0.000188
# {'name': 'correctness_check', 'type': 'function'} 1223936475    0.000034
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475    0.000033
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475    0.019807
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475    0.000035
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475    0.321713
# {'name': 'correctness_check', 'type': 'function'} 1223936475    0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475    0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475    0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475    0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475    0.019761
#
#                                                               Variance time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475            0.000383
# {'name': 'MPI_Init', 'type': 'function'}          1223936475            0.000000
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475            0.000000
# {'name': 'comm', 'type': 'function'}              1223936475            0.000180
# {'name': 'comm_large', 'type': 'function'}        1223936475            0.000168
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475            0.000167
# {'name': 'MPI_Send', 'type': 'function'}          1223936475            0.000000
# {'name': 'comm_small', 'type': 'function'}        1223936475            0.000000
# {'name': 'MPI_Send', 'type': 'function'}          1223936475            0.000000
# {'name': 'comp', 'type': 'function'}              1223936475            0.000371
# {'name': 'comp_small', 'type': 'function'}        1223936475            0.000000
# {'name': 'comp_large', 'type': 'function'}        1223936475            0.000000
# {'name': 'comp', 'type': 'function'}              1223936475            0.000040
# {'name': 'comm', 'type': 'function'}              1223936475            0.000078
# {'name': 'comm_large', 'type': 'function'}        1223936475            0.000078
# {'name': 'MPI_Send', 'type': 'function'}          1223936475            0.000000
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475            0.000077
# {'name': 'comp', 'type': 'function'}              1223936475            0.000000
# {'name': 'comp_large', 'type': 'function'}        1223936475            0.000000
# {'name': 'correctness_check', 'type': 'function'} 1223936475            0.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475            0.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475            0.000043
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475            0.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475            0.000077
# {'name': 'correctness_check', 'type': 'function'} 1223936475            0.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475            0.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475            0.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475            0.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475            0.000000
#
#                                                               Min time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475             0.619995
# {'name': 'MPI_Init', 'type': 'function'}          1223936475             0.000027
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475             0.000072
# {'name': 'comm', 'type': 'function'}              1223936475             0.000010
# {'name': 'comm_large', 'type': 'function'}        1223936475             0.000025
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475             0.001362
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475             0.001942
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000086
# {'name': 'comp', 'type': 'function'}              1223936475             0.000009
# {'name': 'comp_small', 'type': 'function'}        1223936475             0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475             0.000025
# {'name': 'comp', 'type': 'function'}              1223936475             0.000062
# {'name': 'comm', 'type': 'function'}              1223936475             0.000013
# {'name': 'comm_large', 'type': 'function'}        1223936475             0.000101
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000081
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475             0.000149
# {'name': 'comp', 'type': 'function'}              1223936475             0.000008
# {'name': 'comp_large', 'type': 'function'}        1223936475             0.000005
# {'name': 'correctness_check', 'type': 'function'} 1223936475             0.000004
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475             0.020074
# {'name': 'correctness_check', 'type': 'function'} 1223936475             0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475             0.019761
#
#                                                               Max time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475             0.685461
# {'name': 'MPI_Init', 'type': 'function'}          1223936475             0.000044
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475             0.000072
# {'name': 'comm', 'type': 'function'}              1223936475             0.000023
# {'name': 'comm_large', 'type': 'function'}        1223936475             0.000122
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475             0.039014
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475             0.001942
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000086
# {'name': 'comp', 'type': 'function'}              1223936475             0.000012
# {'name': 'comp_small', 'type': 'function'}        1223936475             0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475             0.000035
# {'name': 'comp', 'type': 'function'}              1223936475             0.000083
# {'name': 'comm', 'type': 'function'}              1223936475             0.000014
# {'name': 'comm_large', 'type': 'function'}        1223936475             0.000138
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000095
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475             0.028921
# {'name': 'comp', 'type': 'function'}              1223936475             0.000010
# {'name': 'comp_large', 'type': 'function'}        1223936475             0.000039
# {'name': 'correctness_check', 'type': 'function'} 1223936475             0.000004
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475             0.019772
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475             0.050579
# {'name': 'correctness_check', 'type': 'function'} 1223936475             0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475             0.019761
#
#                                                               Avg time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475             0.639195
# {'name': 'MPI_Init', 'type': 'function'}          1223936475             0.000031
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475             0.000072
# {'name': 'comm', 'type': 'function'}              1223936475             0.000020
# {'name': 'comm_large', 'type': 'function'}        1223936475             0.000042
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475             0.013373
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475             0.001942
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000086
# {'name': 'comp', 'type': 'function'}              1223936475             0.000010
# {'name': 'comp_small', 'type': 'function'}        1223936475             0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475             0.000028
# {'name': 'comp', 'type': 'function'}              1223936475             0.000069
# {'name': 'comm', 'type': 'function'}              1223936475             0.000014
# {'name': 'comm_large', 'type': 'function'}        1223936475             0.000114
# {'name': 'MPI_Send', 'type': 'function'}          1223936475             0.000089
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475             0.015302
# {'name': 'comp', 'type': 'function'}              1223936475             0.000009
# {'name': 'comp_large', 'type': 'function'}        1223936475             0.000023
# {'name': 'correctness_check', 'type': 'function'} 1223936475             0.000004
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475             0.002476
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475             0.040214
# {'name': 'correctness_check', 'type': 'function'} 1223936475             0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475             0.019761
#
#                                                               Total time (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475          5.752758
# {'name': 'MPI_Init', 'type': 'function'}          1223936475          0.000276
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475          0.000072
# {'name': 'comm', 'type': 'function'}              1223936475          0.000183
# {'name': 'comm_large', 'type': 'function'}        1223936475          0.000381
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475          0.120358
# {'name': 'MPI_Send', 'type': 'function'}          1223936475          0.000041
# {'name': 'comm_small', 'type': 'function'}        1223936475          0.001942
# {'name': 'MPI_Send', 'type': 'function'}          1223936475          0.000086
# {'name': 'comp', 'type': 'function'}              1223936475          0.000093
# {'name': 'comp_small', 'type': 'function'}        1223936475          0.000074
# {'name': 'comp_large', 'type': 'function'}        1223936475          0.000224
# {'name': 'comp', 'type': 'function'}              1223936475          0.000555
# {'name': 'comm', 'type': 'function'}              1223936475          0.000109
# {'name': 'comm_large', 'type': 'function'}        1223936475          0.000915
# {'name': 'MPI_Send', 'type': 'function'}          1223936475          0.000713
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475          0.122418
# {'name': 'comp', 'type': 'function'}              1223936475          0.000070
# {'name': 'comp_large', 'type': 'function'}        1223936475          0.000188
# {'name': 'correctness_check', 'type': 'function'} 1223936475          0.000034
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475          0.000033
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475          0.019807
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475          0.000035
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475          0.321713
# {'name': 'correctness_check', 'type': 'function'} 1223936475          0.000024
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475          0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475          0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475          0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475          0.019761
#
#                                                               Calls/rank (min)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475               NaN
# {'name': 'MPI_Init', 'type': 'function'}          1223936475               1.0
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475               1.0
# {'name': 'comm', 'type': 'function'}              1223936475               1.0
# {'name': 'comm_large', 'type': 'function'}        1223936475               1.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475               2.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475               8.0
# {'name': 'comm_small', 'type': 'function'}        1223936475               1.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475               8.0
# {'name': 'comp', 'type': 'function'}              1223936475               1.0
# {'name': 'comp_small', 'type': 'function'}        1223936475               1.0
# {'name': 'comp_large', 'type': 'function'}        1223936475               1.0
# {'name': 'comp', 'type': 'function'}              1223936475               NaN
# {'name': 'comm', 'type': 'function'}              1223936475               2.0
# {'name': 'comm_large', 'type': 'function'}        1223936475               2.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475              16.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475              14.0
# {'name': 'comp', 'type': 'function'}              1223936475               1.0
# {'name': 'comp_large', 'type': 'function'}        1223936475               1.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475               1.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475               1.0
#
#                                                               Calls/rank (avg)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475               NaN
# {'name': 'MPI_Init', 'type': 'function'}          1223936475          1.000000
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475          1.000000
# {'name': 'comm', 'type': 'function'}              1223936475          1.000000
# {'name': 'comm_large', 'type': 'function'}        1223936475          1.000000
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475          3.555556
# {'name': 'MPI_Send', 'type': 'function'}          1223936475          8.000000
# {'name': 'comm_small', 'type': 'function'}        1223936475          1.000000
# {'name': 'MPI_Send', 'type': 'function'}          1223936475          8.000000
# {'name': 'comp', 'type': 'function'}              1223936475          1.000000
# {'name': 'comp_small', 'type': 'function'}        1223936475          1.000000
# {'name': 'comp_large', 'type': 'function'}        1223936475          1.000000
# {'name': 'comp', 'type': 'function'}              1223936475               NaN
# {'name': 'comm', 'type': 'function'}              1223936475          2.000000
# {'name': 'comm_large', 'type': 'function'}        1223936475          2.000000
# {'name': 'MPI_Send', 'type': 'function'}          1223936475         16.000000
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475         14.000000
# {'name': 'comp', 'type': 'function'}              1223936475          1.000000
# {'name': 'comp_large', 'type': 'function'}        1223936475          1.000000
# {'name': 'correctness_check', 'type': 'function'} 1223936475          1.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475          1.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475          1.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475          1.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475          1.000000
# {'name': 'correctness_check', 'type': 'function'} 1223936475          1.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475          1.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475          1.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475          1.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475          1.000000
#
#                                                               Calls/rank (max)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475               NaN
# {'name': 'MPI_Init', 'type': 'function'}          1223936475               1.0
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475               1.0
# {'name': 'comm', 'type': 'function'}              1223936475               1.0
# {'name': 'comm_large', 'type': 'function'}        1223936475               1.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475              16.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475               8.0
# {'name': 'comm_small', 'type': 'function'}        1223936475               1.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475               8.0
# {'name': 'comp', 'type': 'function'}              1223936475               1.0
# {'name': 'comp_small', 'type': 'function'}        1223936475               1.0
# {'name': 'comp_large', 'type': 'function'}        1223936475               1.0
# {'name': 'comp', 'type': 'function'}              1223936475               NaN
# {'name': 'comm', 'type': 'function'}              1223936475               2.0
# {'name': 'comm_large', 'type': 'function'}        1223936475               2.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475              16.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475              14.0
# {'name': 'comp', 'type': 'function'}              1223936475               1.0
# {'name': 'comp_large', 'type': 'function'}        1223936475               1.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475               1.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475               1.0
#
#                                                               Calls/rank (total)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475                 NaN
# {'name': 'MPI_Init', 'type': 'function'}          1223936475                 9.0
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475                 1.0
# {'name': 'comm', 'type': 'function'}              1223936475                 9.0
# {'name': 'comm_large', 'type': 'function'}        1223936475                 9.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475                32.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475                 8.0
# {'name': 'comm_small', 'type': 'function'}        1223936475                 1.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475                 8.0
# {'name': 'comp', 'type': 'function'}              1223936475                 1.0
# {'name': 'comp_small', 'type': 'function'}        1223936475                 1.0
# {'name': 'comp_large', 'type': 'function'}        1223936475                 8.0
# {'name': 'comp', 'type': 'function'}              1223936475                 NaN
# {'name': 'comm', 'type': 'function'}              1223936475                16.0
# {'name': 'comm_large', 'type': 'function'}        1223936475                16.0
# {'name': 'MPI_Send', 'type': 'function'}          1223936475               128.0
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475               112.0
# {'name': 'comp', 'type': 'function'}              1223936475                 8.0
# {'name': 'comp_large', 'type': 'function'}        1223936475                 8.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475                 8.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475                 8.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475                 8.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475                 8.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475                 8.0
# {'name': 'correctness_check', 'type': 'function'} 1223936475                 1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475                 1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475                 1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475                 1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475                 1.0
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              1223936475               main
# {'name': 'MPI_Init', 'type': 'function'}          1223936475           MPI_Init
# {'name': 'data_init_runtime', 'type': 'function'} 1223936475  data_init_runtime
# {'name': 'comm', 'type': 'function'}              1223936475               comm
# {'name': 'comm_large', 'type': 'function'}        1223936475         comm_large
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475           MPI_Recv
# {'name': 'MPI_Send', 'type': 'function'}          1223936475           MPI_Send
# {'name': 'comm_small', 'type': 'function'}        1223936475         comm_small
# {'name': 'MPI_Send', 'type': 'function'}          1223936475           MPI_Send
# {'name': 'comp', 'type': 'function'}              1223936475               comp
# {'name': 'comp_small', 'type': 'function'}        1223936475         comp_small
# {'name': 'comp_large', 'type': 'function'}        1223936475         comp_large
# {'name': 'comp', 'type': 'function'}              1223936475               comp
# {'name': 'comm', 'type': 'function'}              1223936475               comm
# {'name': 'comm_large', 'type': 'function'}        1223936475         comm_large
# {'name': 'MPI_Send', 'type': 'function'}          1223936475           MPI_Send
# {'name': 'MPI_Recv', 'type': 'function'}          1223936475           MPI_Recv
# {'name': 'comp', 'type': 'function'}              1223936475               comp
# {'name': 'comp_large', 'type': 'function'}        1223936475         comp_large
# {'name': 'correctness_check', 'type': 'function'} 1223936475  correctness_check
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       MPI_Finalize
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475    MPI_Initialized
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475      MPI_Finalized
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       MPI_Comm_dup
# {'name': 'correctness_check', 'type': 'function'} 1223936475  correctness_check
# {'name': 'MPI_Finalize', 'type': 'function'}      1223936475       MPI_Finalize
# {'name': 'MPI_Initialized', 'type': 'function'}   1223936475    MPI_Initialized
# {'name': 'MPI_Finalized', 'type': 'function'}     1223936475      MPI_Finalized
# {'name': 'MPI_Comm_dup', 'type': 'function'}      1223936475       MPI_Comm_dup

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 1223936475               2.11.0               9
#
#                                                  spot.metrics  \
# profile
# 1223936475  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 1223936475                                            2
#
#                                                  spot.options  spot.channels  \
# profile
# 1223936475  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#            cali.channel spot:node.order    spot:output spot:profile.mpi  \
# profile
# 1223936475         spot            true  p8-a1024.cali             true
#
#            spot:region.count spot:time.exclusive spot:time.variance  \
# profile
# 1223936475              true                true               true
#
#             launchdate                                          libraries  \
# profile
# 1223936475  1729092251  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                              cmdline cluster algorithm programming_model  \
# profile
# 1223936475  [./sample-sort, 1024, 8]       c    sample               mpi
#
#            data_type  size_of_data_type  input_size input_type  num_procs  \
# profile
# 1223936475       int                  4        1024     Random          9
#
#            scalability  group_num implementation_source
# profile
# 1223936475        weak          3           handwritten
