# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %%
#1_trial is a name of a folder containing the cali files, you may create a folder with a different name and replace the folder name here
tk = th.Thicket.from_caliperreader("results/cali/128_65536.cali")

# %%
print(tk.tree(metric_column="Avg time/rank", precision=5))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 2.40835 main
# ├─ 0.00004 MPI_Init
# ├─ 0.03392 main
# │  ├─ 0.00277 data_init_runtime
# │  ├─ 0.03306 comm
# │  │  └─ 0.03304 comm_large
# │  │     ├─ 0.01545 MPI_Scatter
# │  │     ├─ 0.03134 MPI_Recv
# │  │     └─ 0.00188 MPI_Send
# │  ├─ 0.00078 comp
# │  │  └─ 0.00076 comp_large
# │  └─ 0.00035 correctness_check
# ├─ 0.00001 MPI_Finalize
# ├─ 0.00001 MPI_Initialized
# ├─ 0.00001 MPI_Finalized
# └─ 0.14121 MPI_Comm_dup
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 2.41 indices: {'profile': 2765023333})
# █ 2.17 - 2.41
# █ 1.69 - 2.17
# █ 1.20 - 1.69
# █ 0.72 - 1.20
# █ 0.24 - 0.72
# █ 0.00 - 0.24
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.dataframe
# Out:
#                                                                nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333   1.0
# {'name': 'MPI_Init', 'type': 'function'}          2765023333   2.0
# {'name': 'main', 'type': 'function'}              2765023333   3.0
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333   4.0
# {'name': 'comm', 'type': 'function'}              2765023333   5.0
# {'name': 'comm_large', 'type': 'function'}        2765023333   6.0
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333   7.0
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333  10.0
# {'name': 'MPI_Send', 'type': 'function'}          2765023333  16.0
# {'name': 'comp', 'type': 'function'}              2765023333   8.0
# {'name': 'comp_large', 'type': 'function'}        2765023333   9.0
# {'name': 'correctness_check', 'type': 'function'} 2765023333  11.0
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333  12.0
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333  13.0
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333  14.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333  15.0
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333  regionprofile
# {'name': 'MPI_Init', 'type': 'function'}          2765023333  regionprofile
# {'name': 'main', 'type': 'function'}              2765023333  regionprofile
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333  regionprofile
# {'name': 'comm', 'type': 'function'}              2765023333  regionprofile
# {'name': 'comm_large', 'type': 'function'}        2765023333  regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          2765023333  regionprofile
# {'name': 'comp', 'type': 'function'}              2765023333  regionprofile
# {'name': 'comp_large', 'type': 'function'}        2765023333  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2765023333  regionprofile
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333  regionprofile
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333  regionprofile
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333  regionprofile
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333       2.349218
# {'name': 'MPI_Init', 'type': 'function'}          2765023333       0.000028
# {'name': 'main', 'type': 'function'}              2765023333       0.003329
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333       0.002768
# {'name': 'comm', 'type': 'function'}              2765023333       0.002666
# {'name': 'comm_large', 'type': 'function'}        2765023333       0.002649
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333       0.000305
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333       0.023126
# {'name': 'MPI_Send', 'type': 'function'}          2765023333       0.000023
# {'name': 'comp', 'type': 'function'}              2765023333       0.000625
# {'name': 'comp_large', 'type': 'function'}        2765023333       0.000614
# {'name': 'correctness_check', 'type': 'function'} 2765023333       0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333       0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333       0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333       0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333       0.000305
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333       2.415813
# {'name': 'MPI_Init', 'type': 'function'}          2765023333       0.000078
# {'name': 'main', 'type': 'function'}              2765023333       0.089086
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333       0.002768
# {'name': 'comm', 'type': 'function'}              2765023333       0.084764
# {'name': 'comm_large', 'type': 'function'}        2765023333       0.084716
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333       0.029355
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333       0.055543
# {'name': 'MPI_Send', 'type': 'function'}          2765023333       0.014586
# {'name': 'comp', 'type': 'function'}              2765023333       0.004583
# {'name': 'comp_large', 'type': 'function'}        2765023333       0.004525
# {'name': 'correctness_check', 'type': 'function'} 2765023333       0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333       0.000023
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333       0.000015
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333       0.000016
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333       0.150116
#
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333       2.408355
# {'name': 'MPI_Init', 'type': 'function'}          2765023333       0.000036
# {'name': 'main', 'type': 'function'}              2765023333       0.033919
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333       0.002768
# {'name': 'comm', 'type': 'function'}              2765023333       0.033064
# {'name': 'comm_large', 'type': 'function'}        2765023333       0.033039
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333       0.015446
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333       0.031336
# {'name': 'MPI_Send', 'type': 'function'}          2765023333       0.001885
# {'name': 'comp', 'type': 'function'}              2765023333       0.000783
# {'name': 'comp_large', 'type': 'function'}        2765023333       0.000765
# {'name': 'correctness_check', 'type': 'function'} 2765023333       0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333       0.000006
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333       0.000006
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333       0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333       0.141214
#
#                                                               Total time  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333  308.269438
# {'name': 'MPI_Init', 'type': 'function'}          2765023333    0.004559
# {'name': 'main', 'type': 'function'}              2765023333    4.341604
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333    0.002768
# {'name': 'comm', 'type': 'function'}              2765023333    4.232241
# {'name': 'comm_large', 'type': 'function'}        2765023333    4.228955
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333    1.977121
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333    2.005532
# {'name': 'MPI_Send', 'type': 'function'}          2765023333    0.239357
# {'name': 'comp', 'type': 'function'}              2765023333    0.100248
# {'name': 'comp_large', 'type': 'function'}        2765023333    0.097907
# {'name': 'correctness_check', 'type': 'function'} 2765023333    0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333    0.000768
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333    0.000717
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333    0.000600
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333   18.075396
#
#                                                               Variance time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333            0.000138
# {'name': 'MPI_Init', 'type': 'function'}          2765023333            0.000000
# {'name': 'main', 'type': 'function'}              2765023333            0.000476
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333            0.000000
# {'name': 'comm', 'type': 'function'}              2765023333            0.000464
# {'name': 'comm_large', 'type': 'function'}        2765023333            0.000464
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333            0.000118
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333            0.000111
# {'name': 'MPI_Send', 'type': 'function'}          2765023333            0.000005
# {'name': 'comp', 'type': 'function'}              2765023333            0.000000
# {'name': 'comp_large', 'type': 'function'}        2765023333            0.000000
# {'name': 'correctness_check', 'type': 'function'} 2765023333            0.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333            0.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333            0.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333            0.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333            0.000242
#
#                                                               Min time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333             2.189639
# {'name': 'MPI_Init', 'type': 'function'}          2765023333             0.000028
# {'name': 'main', 'type': 'function'}              2765023333             0.000028
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333             0.002768
# {'name': 'comm', 'type': 'function'}              2765023333             0.000017
# {'name': 'comm_large', 'type': 'function'}        2765023333             0.000033
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333             0.000305
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333             0.023126
# {'name': 'MPI_Send', 'type': 'function'}          2765023333             0.000023
# {'name': 'comp', 'type': 'function'}              2765023333             0.000009
# {'name': 'comp_large', 'type': 'function'}        2765023333             0.000614
# {'name': 'correctness_check', 'type': 'function'} 2765023333             0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333             0.000004
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333             0.000305
#
#                                                               Max time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333             2.310761
# {'name': 'MPI_Init', 'type': 'function'}          2765023333             0.000078
# {'name': 'main', 'type': 'function'}              2765023333             0.000326
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333             0.002768
# {'name': 'comm', 'type': 'function'}              2765023333             0.000055
# {'name': 'comm_large', 'type': 'function'}        2765023333             0.000106
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333             0.029355
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333             0.055543
# {'name': 'MPI_Send', 'type': 'function'}          2765023333             0.014586
# {'name': 'comp', 'type': 'function'}              2765023333             0.000058
# {'name': 'comp_large', 'type': 'function'}        2765023333             0.004525
# {'name': 'correctness_check', 'type': 'function'} 2765023333             0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333             0.000023
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333             0.000015
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333             0.000016
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333             0.150116
#
#                                                               Avg time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333             2.233170
# {'name': 'MPI_Init', 'type': 'function'}          2765023333             0.000036
# {'name': 'main', 'type': 'function'}              2765023333             0.000047
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333             0.002768
# {'name': 'comm', 'type': 'function'}              2765023333             0.000026
# {'name': 'comm_large', 'type': 'function'}        2765023333             0.000054
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333             0.015446
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333             0.031336
# {'name': 'MPI_Send', 'type': 'function'}          2765023333             0.001885
# {'name': 'comp', 'type': 'function'}              2765023333             0.000018
# {'name': 'comp_large', 'type': 'function'}        2765023333             0.000765
# {'name': 'correctness_check', 'type': 'function'} 2765023333             0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333             0.000006
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333             0.000006
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333             0.141214
#
#                                                               Total time (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333        285.845794
# {'name': 'MPI_Init', 'type': 'function'}          2765023333          0.004559
# {'name': 'main', 'type': 'function'}              2765023333          0.006001
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333          0.002768
# {'name': 'comm', 'type': 'function'}              2765023333          0.003287
# {'name': 'comm_large', 'type': 'function'}        2765023333          0.006945
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333          1.977121
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333          2.005532
# {'name': 'MPI_Send', 'type': 'function'}          2765023333          0.239357
# {'name': 'comp', 'type': 'function'}              2765023333          0.002341
# {'name': 'comp_large', 'type': 'function'}        2765023333          0.097907
# {'name': 'correctness_check', 'type': 'function'} 2765023333          0.000346
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333          0.000768
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333          0.000717
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333          0.000600
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333         18.075396
#
#                                                               Calls/rank (min)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333               NaN
# {'name': 'MPI_Init', 'type': 'function'}          2765023333               1.0
# {'name': 'main', 'type': 'function'}              2765023333               1.0
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333               1.0
# {'name': 'comm', 'type': 'function'}              2765023333               2.0
# {'name': 'comm_large', 'type': 'function'}        2765023333               2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333               1.0
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333               1.0
# {'name': 'MPI_Send', 'type': 'function'}          2765023333               1.0
# {'name': 'comp', 'type': 'function'}              2765023333               1.0
# {'name': 'comp_large', 'type': 'function'}        2765023333               1.0
# {'name': 'correctness_check', 'type': 'function'} 2765023333               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333               1.0
#
#                                                               Calls/rank (avg)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333               NaN
# {'name': 'MPI_Init', 'type': 'function'}          2765023333          1.000000
# {'name': 'main', 'type': 'function'}              2765023333          1.000000
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333          1.000000
# {'name': 'comm', 'type': 'function'}              2765023333          2.984375
# {'name': 'comm_large', 'type': 'function'}        2765023333          2.984375
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333          1.000000
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333          1.984375
# {'name': 'MPI_Send', 'type': 'function'}          2765023333          1.000000
# {'name': 'comp', 'type': 'function'}              2765023333          1.992188
# {'name': 'comp_large', 'type': 'function'}        2765023333          1.992188
# {'name': 'correctness_check', 'type': 'function'} 2765023333          1.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333          1.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333          1.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333          1.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333          1.000000
#
#                                                               Calls/rank (max)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333               NaN
# {'name': 'MPI_Init', 'type': 'function'}          2765023333               1.0
# {'name': 'main', 'type': 'function'}              2765023333               1.0
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333               1.0
# {'name': 'comm', 'type': 'function'}              2765023333               8.0
# {'name': 'comm_large', 'type': 'function'}        2765023333               8.0
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333               1.0
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333               7.0
# {'name': 'MPI_Send', 'type': 'function'}          2765023333               1.0
# {'name': 'comp', 'type': 'function'}              2765023333               8.0
# {'name': 'comp_large', 'type': 'function'}        2765023333               8.0
# {'name': 'correctness_check', 'type': 'function'} 2765023333               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333               1.0
#
#                                                               Calls/rank (total)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333                 NaN
# {'name': 'MPI_Init', 'type': 'function'}          2765023333               128.0
# {'name': 'main', 'type': 'function'}              2765023333               128.0
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333                 1.0
# {'name': 'comm', 'type': 'function'}              2765023333               382.0
# {'name': 'comm_large', 'type': 'function'}        2765023333               382.0
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333               128.0
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333               127.0
# {'name': 'MPI_Send', 'type': 'function'}          2765023333               127.0
# {'name': 'comp', 'type': 'function'}              2765023333               255.0
# {'name': 'comp_large', 'type': 'function'}        2765023333               255.0
# {'name': 'correctness_check', 'type': 'function'} 2765023333                 1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333               128.0
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333               128.0
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333               128.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333               128.0
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              2765023333               main
# {'name': 'MPI_Init', 'type': 'function'}          2765023333           MPI_Init
# {'name': 'main', 'type': 'function'}              2765023333               main
# {'name': 'data_init_runtime', 'type': 'function'} 2765023333  data_init_runtime
# {'name': 'comm', 'type': 'function'}              2765023333               comm
# {'name': 'comm_large', 'type': 'function'}        2765023333         comm_large
# {'name': 'MPI_Scatter', 'type': 'function'}       2765023333        MPI_Scatter
# {'name': 'MPI_Recv', 'type': 'function'}          2765023333           MPI_Recv
# {'name': 'MPI_Send', 'type': 'function'}          2765023333           MPI_Send
# {'name': 'comp', 'type': 'function'}              2765023333               comp
# {'name': 'comp_large', 'type': 'function'}        2765023333         comp_large
# {'name': 'correctness_check', 'type': 'function'} 2765023333  correctness_check
# {'name': 'MPI_Finalize', 'type': 'function'}      2765023333       MPI_Finalize
# {'name': 'MPI_Initialized', 'type': 'function'}   2765023333    MPI_Initialized
# {'name': 'MPI_Finalized', 'type': 'function'}     2765023333      MPI_Finalized
# {'name': 'MPI_Comm_dup', 'type': 'function'}      2765023333       MPI_Comm_dup

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 2765023333               2.11.0             128
#
#                                                  spot.metrics  \
# profile
# 2765023333  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 2765023333                                            2
#
#                                                  spot.options  spot.channels  \
# profile
# 2765023333  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#            cali.channel spot:node.order                  spot:output  \
# profile
# 2765023333         spot            true  results/cali/128_65536.cali
#
#            spot:profile.mpi spot:region.count spot:time.exclusive  \
# profile
# 2765023333             true              true                true
#
#            spot:time.variance  launchdate  \
# profile
# 2765023333               true  1728867822
#
#                                                     libraries  \
# profile
# 2765023333  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                      cmdline cluster algorithm programming_model data_type  \
# profile
# 2765023333  [./merge, 65536]       c     merge               mpi       int
#
#             size_of_data_type  input_size input_type  num_procs scalability  \
# profile
# 2765023333                  4       65536     Random        128        weak
#
#             group_num implementation_source
# profile
# 2765023333          3           handwritten
