# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %%
#1_trial is a name of a folder containing the cali files, you may create a folder with a different name and replace the folder name here
tk = th.Thicket.from_caliperreader("results/cali/256_268435456.cali")

# %%
print(tk.tree(metric_column="Avg time/rank", precision=5))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 26.42026 main
# ├─ 0.00004 MPI_Init
# ├─ 2.16805 main
# │  ├─ 0.03342 data_init_runtime
# │  ├─ 1.99352 comp
# │  │  └─ 1.99346 comp_large
# │  ├─ 0.10944 comm
# │  │  └─ 0.10940 comm_large
# │  │     ├─ 0.17937 MPI_Recv
# │  │     └─ 0.01974 MPI_Send
# │  └─ 1.42442 correctness_check
# ├─ 0.00001 MPI_Finalize
# ├─ 0.00001 MPI_Initialized
# ├─ 0.00001 MPI_Finalized
# └─ 21.95693 MPI_Comm_dup
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 26.42 indices: {'profile': 554544421})
# █ 23.78 - 26.42
# █ 18.49 - 23.78
# █ 13.21 - 18.49
# █ 7.93 - 13.21
# █ 2.64 - 7.93
# █ 0.00 - 2.64
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421   1.0
# {'name': 'MPI_Init', 'type': 'function'}          554544421   2.0
# {'name': 'main', 'type': 'function'}              554544421   3.0
# {'name': 'data_init_runtime', 'type': 'function'} 554544421   4.0
# {'name': 'comp', 'type': 'function'}              554544421   5.0
# {'name': 'comp_large', 'type': 'function'}        554544421   6.0
# {'name': 'comm', 'type': 'function'}              554544421   7.0
# {'name': 'comm_large', 'type': 'function'}        554544421   8.0
# {'name': 'MPI_Recv', 'type': 'function'}          554544421   9.0
# {'name': 'MPI_Send', 'type': 'function'}          554544421  15.0
# {'name': 'correctness_check', 'type': 'function'} 554544421  10.0
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421  11.0
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421  12.0
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421  13.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421  14.0
#
#                                                               spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421  regionprofile
# {'name': 'MPI_Init', 'type': 'function'}          554544421  regionprofile
# {'name': 'main', 'type': 'function'}              554544421  regionprofile
# {'name': 'data_init_runtime', 'type': 'function'} 554544421  regionprofile
# {'name': 'comp', 'type': 'function'}              554544421  regionprofile
# {'name': 'comp_large', 'type': 'function'}        554544421  regionprofile
# {'name': 'comm', 'type': 'function'}              554544421  regionprofile
# {'name': 'comm_large', 'type': 'function'}        554544421  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          554544421  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          554544421  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 554544421  regionprofile
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421  regionprofile
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421  regionprofile
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421  regionprofile
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421  regionprofile
#
#                                                              Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421      26.362605
# {'name': 'MPI_Init', 'type': 'function'}          554544421       0.000027
# {'name': 'main', 'type': 'function'}              554544421       1.712484
# {'name': 'data_init_runtime', 'type': 'function'} 554544421       0.032013
# {'name': 'comp', 'type': 'function'}              554544421       1.671967
# {'name': 'comp_large', 'type': 'function'}        554544421       1.671919
# {'name': 'comm', 'type': 'function'}              554544421       0.003362
# {'name': 'comm_large', 'type': 'function'}        554544421       0.003346
# {'name': 'MPI_Recv', 'type': 'function'}          554544421       0.003091
# {'name': 'MPI_Send', 'type': 'function'}          554544421       0.001834
# {'name': 'correctness_check', 'type': 'function'} 554544421       1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421       0.000007
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421       0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421       0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421       0.000754
#
#                                                              Max time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421      26.426839
# {'name': 'MPI_Init', 'type': 'function'}          554544421       0.000119
# {'name': 'main', 'type': 'function'}              554544421      24.159943
# {'name': 'data_init_runtime', 'type': 'function'} 554544421       0.072812
# {'name': 'comp', 'type': 'function'}              554544421      20.160811
# {'name': 'comp_large', 'type': 'function'}        554544421      20.160606
# {'name': 'comm', 'type': 'function'}              554544421       1.817188
# {'name': 'comm_large', 'type': 'function'}        554544421       1.817128
# {'name': 'MPI_Recv', 'type': 'function'}          554544421       1.808471
# {'name': 'MPI_Send', 'type': 'function'}          554544421       1.718439
# {'name': 'correctness_check', 'type': 'function'} 554544421       1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421       0.000020
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421       0.000035
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421       0.000028
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421      22.424387
#
#                                                              Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421      26.420261
# {'name': 'MPI_Init', 'type': 'function'}          554544421       0.000038
# {'name': 'main', 'type': 'function'}              554544421       2.168050
# {'name': 'data_init_runtime', 'type': 'function'} 554544421       0.033420
# {'name': 'comp', 'type': 'function'}              554544421       1.993519
# {'name': 'comp_large', 'type': 'function'}        554544421       1.993461
# {'name': 'comm', 'type': 'function'}              554544421       0.109440
# {'name': 'comm_large', 'type': 'function'}        554544421       0.109403
# {'name': 'MPI_Recv', 'type': 'function'}          554544421       0.179370
# {'name': 'MPI_Send', 'type': 'function'}          554544421       0.019743
# {'name': 'correctness_check', 'type': 'function'} 554544421       1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421       0.000010
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421       0.000006
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421       0.000006
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421      21.956929
#
#                                                               Total time  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421  6763.586710
# {'name': 'MPI_Init', 'type': 'function'}          554544421     0.009729
# {'name': 'main', 'type': 'function'}              554544421   555.020711
# {'name': 'data_init_runtime', 'type': 'function'} 554544421     8.555503
# {'name': 'comp', 'type': 'function'}              554544421   510.340919
# {'name': 'comp_large', 'type': 'function'}        554544421   510.326124
# {'name': 'comm', 'type': 'function'}              554544421    28.016602
# {'name': 'comm_large', 'type': 'function'}        554544421    28.007043
# {'name': 'MPI_Recv', 'type': 'function'}          554544421    22.959331
# {'name': 'MPI_Send', 'type': 'function'}          554544421     5.034361
# {'name': 'correctness_check', 'type': 'function'} 554544421     1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421     0.002530
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421     0.001654
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421     0.001533
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421  5620.973860
#
#                                                              Variance time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421            0.000033
# {'name': 'MPI_Init', 'type': 'function'}          554544421            0.000000
# {'name': 'main', 'type': 'function'}              554544421            3.013445
# {'name': 'data_init_runtime', 'type': 'function'} 554544421            0.000010
# {'name': 'comp', 'type': 'function'}              554544421            1.930701
# {'name': 'comp_large', 'type': 'function'}        554544421            1.930651
# {'name': 'comm', 'type': 'function'}              554544421            0.117584
# {'name': 'comm_large', 'type': 'function'}        554544421            0.117576
# {'name': 'MPI_Recv', 'type': 'function'}          554544421            0.192886
# {'name': 'MPI_Send', 'type': 'function'}          554544421            0.011589
# {'name': 'correctness_check', 'type': 'function'} 554544421            0.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421            0.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421            0.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421            0.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421            2.989758
#
#                                                              Min time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421             2.250545
# {'name': 'MPI_Init', 'type': 'function'}          554544421             0.000027
# {'name': 'main', 'type': 'function'}              554544421             0.002158
# {'name': 'data_init_runtime', 'type': 'function'} 554544421             0.032013
# {'name': 'comp', 'type': 'function'}              554544421             0.000031
# {'name': 'comp_large', 'type': 'function'}        554544421             1.671919
# {'name': 'comm', 'type': 'function'}              554544421             0.000016
# {'name': 'comm_large', 'type': 'function'}        554544421             0.000022
# {'name': 'MPI_Recv', 'type': 'function'}          554544421             0.003091
# {'name': 'MPI_Send', 'type': 'function'}          554544421             0.001834
# {'name': 'correctness_check', 'type': 'function'} 554544421             1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421             0.000007
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421             0.000754
#
#                                                              Max time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421             2.363427
# {'name': 'MPI_Init', 'type': 'function'}          554544421             0.000119
# {'name': 'main', 'type': 'function'}              554544421             1.467818
# {'name': 'data_init_runtime', 'type': 'function'} 554544421             0.072812
# {'name': 'comp', 'type': 'function'}              554544421             0.000204
# {'name': 'comp_large', 'type': 'function'}        554544421            20.160606
# {'name': 'comm', 'type': 'function'}              554544421             0.000161
# {'name': 'comm_large', 'type': 'function'}        554544421             0.000174
# {'name': 'MPI_Recv', 'type': 'function'}          554544421             1.808471
# {'name': 'MPI_Send', 'type': 'function'}          554544421             1.718439
# {'name': 'correctness_check', 'type': 'function'} 554544421             1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421             0.000020
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421             0.000035
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421             0.000028
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421            22.424387
#
#                                                              Avg time/rank (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421             2.295221
# {'name': 'MPI_Init', 'type': 'function'}          554544421             0.000038
# {'name': 'main', 'type': 'function'}              554544421             0.026107
# {'name': 'data_init_runtime', 'type': 'function'} 554544421             0.033420
# {'name': 'comp', 'type': 'function'}              554544421             0.000058
# {'name': 'comp_large', 'type': 'function'}        554544421             1.993461
# {'name': 'comm', 'type': 'function'}              554544421             0.000037
# {'name': 'comm_large', 'type': 'function'}        554544421             0.000052
# {'name': 'MPI_Recv', 'type': 'function'}          554544421             0.179370
# {'name': 'MPI_Send', 'type': 'function'}          554544421             0.019743
# {'name': 'correctness_check', 'type': 'function'} 554544421             1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421             0.000010
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421             0.000006
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421             0.000006
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421            21.956929
#
#                                                              Total time (exc)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421        587.576693
# {'name': 'MPI_Init', 'type': 'function'}          554544421          0.009729
# {'name': 'main', 'type': 'function'}              554544421          6.683270
# {'name': 'data_init_runtime', 'type': 'function'} 554544421          8.555503
# {'name': 'comp', 'type': 'function'}              554544421          0.014795
# {'name': 'comp_large', 'type': 'function'}        554544421        510.326124
# {'name': 'comm', 'type': 'function'}              554544421          0.009559
# {'name': 'comm_large', 'type': 'function'}        554544421          0.013352
# {'name': 'MPI_Recv', 'type': 'function'}          554544421         22.959331
# {'name': 'MPI_Send', 'type': 'function'}          554544421          5.034361
# {'name': 'correctness_check', 'type': 'function'} 554544421          1.424418
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421          0.002530
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421          0.001654
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421          0.001533
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421       5620.973860
#
#                                                              Calls/rank (min)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421               NaN
# {'name': 'MPI_Init', 'type': 'function'}          554544421               1.0
# {'name': 'main', 'type': 'function'}              554544421               1.0
# {'name': 'data_init_runtime', 'type': 'function'} 554544421               1.0
# {'name': 'comp', 'type': 'function'}              554544421               1.0
# {'name': 'comp_large', 'type': 'function'}        554544421               1.0
# {'name': 'comm', 'type': 'function'}              554544421               1.0
# {'name': 'comm_large', 'type': 'function'}        554544421               1.0
# {'name': 'MPI_Recv', 'type': 'function'}          554544421               1.0
# {'name': 'MPI_Send', 'type': 'function'}          554544421               1.0
# {'name': 'correctness_check', 'type': 'function'} 554544421               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421               1.0
#
#                                                              Calls/rank (avg)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421               NaN
# {'name': 'MPI_Init', 'type': 'function'}          554544421          1.000000
# {'name': 'main', 'type': 'function'}              554544421          1.000000
# {'name': 'data_init_runtime', 'type': 'function'} 554544421          1.000000
# {'name': 'comp', 'type': 'function'}              554544421          1.996094
# {'name': 'comp_large', 'type': 'function'}        554544421          1.996094
# {'name': 'comm', 'type': 'function'}              554544421          1.992188
# {'name': 'comm_large', 'type': 'function'}        554544421          1.992188
# {'name': 'MPI_Recv', 'type': 'function'}          554544421          1.992188
# {'name': 'MPI_Send', 'type': 'function'}          554544421          1.000000
# {'name': 'correctness_check', 'type': 'function'} 554544421          1.000000
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421          1.000000
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421          1.000000
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421          1.000000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421          1.000000
#
#                                                              Calls/rank (max)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421               NaN
# {'name': 'MPI_Init', 'type': 'function'}          554544421               1.0
# {'name': 'main', 'type': 'function'}              554544421               1.0
# {'name': 'data_init_runtime', 'type': 'function'} 554544421               1.0
# {'name': 'comp', 'type': 'function'}              554544421               9.0
# {'name': 'comp_large', 'type': 'function'}        554544421               9.0
# {'name': 'comm', 'type': 'function'}              554544421               8.0
# {'name': 'comm_large', 'type': 'function'}        554544421               8.0
# {'name': 'MPI_Recv', 'type': 'function'}          554544421               8.0
# {'name': 'MPI_Send', 'type': 'function'}          554544421               1.0
# {'name': 'correctness_check', 'type': 'function'} 554544421               1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421               1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421               1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421               1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421               1.0
#
#                                                              Calls/rank (total)  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421                 NaN
# {'name': 'MPI_Init', 'type': 'function'}          554544421               256.0
# {'name': 'main', 'type': 'function'}              554544421               256.0
# {'name': 'data_init_runtime', 'type': 'function'} 554544421               256.0
# {'name': 'comp', 'type': 'function'}              554544421               511.0
# {'name': 'comp_large', 'type': 'function'}        554544421               511.0
# {'name': 'comm', 'type': 'function'}              554544421               510.0
# {'name': 'comm_large', 'type': 'function'}        554544421               510.0
# {'name': 'MPI_Recv', 'type': 'function'}          554544421               255.0
# {'name': 'MPI_Send', 'type': 'function'}          554544421               255.0
# {'name': 'correctness_check', 'type': 'function'} 554544421                 1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421               256.0
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421               256.0
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421               256.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421               256.0
#
#                                                                           name
# node                                              profile
# {'name': 'main', 'type': 'function'}              554544421               main
# {'name': 'MPI_Init', 'type': 'function'}          554544421           MPI_Init
# {'name': 'main', 'type': 'function'}              554544421               main
# {'name': 'data_init_runtime', 'type': 'function'} 554544421  data_init_runtime
# {'name': 'comp', 'type': 'function'}              554544421               comp
# {'name': 'comp_large', 'type': 'function'}        554544421         comp_large
# {'name': 'comm', 'type': 'function'}              554544421               comm
# {'name': 'comm_large', 'type': 'function'}        554544421         comm_large
# {'name': 'MPI_Recv', 'type': 'function'}          554544421           MPI_Recv
# {'name': 'MPI_Send', 'type': 'function'}          554544421           MPI_Send
# {'name': 'correctness_check', 'type': 'function'} 554544421  correctness_check
# {'name': 'MPI_Finalize', 'type': 'function'}      554544421       MPI_Finalize
# {'name': 'MPI_Initialized', 'type': 'function'}   554544421    MPI_Initialized
# {'name': 'MPI_Finalized', 'type': 'function'}     554544421      MPI_Finalized
# {'name': 'MPI_Comm_dup', 'type': 'function'}      554544421       MPI_Comm_dup

# %%
tk.metadata
# Out:
#           cali.caliper.version  mpi.world.size  \
# profile
# 554544421               2.11.0             256
#
#                                                 spot.metrics  \
# profile
# 554544421  min#inclusive#sum#time.duration,max#inclusive#...
#
#           spot.timeseries.metrics  spot.format.version  \
# profile
# 554544421                                            2
#
#                                                 spot.options  spot.channels  \
# profile
# 554544421  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#           cali.channel spot:node.order                      spot:output  \
# profile
# 554544421         spot            true  results/cali/256_268435456.cali
#
#           spot:profile.mpi spot:region.count spot:time.exclusive  \
# profile
# 554544421             true              true                true
#
#           spot:time.variance  launchdate  \
# profile
# 554544421               true  1728917829
#
#                                                    libraries  \
# profile
# 554544421  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                         cmdline cluster algorithm programming_model data_type  \
# profile
# 554544421  [./merge, 268435456]       c     merge               mpi       int
#
#            size_of_data_type  input_size input_type  num_procs scalability  \
# profile
# 554544421                  4   268435456     Random        256        weak
#
#            group_num implementation_source
# profile
# 554544421          3           handwritten
